# %% [markdown]
# <a href="https://colab.research.google.com/github/Rfky1Pratama/sistem-panen/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sistem Pencatatan Hasil Panen Digital

nama_komoditas = "Jagung"
hasil_panen = 500  # kg
harga_per_kg = 7000

total = hasil_panen * harga_per_kg

print("SISTEM PENCATATAN HASIL PANEN")
print("Komoditas :", nama_komoditas)
print("Hasil panen :", hasil_panen, "kg")
print("Harga per kg : Rp", harga_per_kg)
print("Total nilai panen : Rp", total)
# Out:
# SISTEM PENCATATAN HASIL PANEN
# Komoditas : Jagung
# Hasil panen : 500 kg
# Harga per kg : Rp 7000
# Total nilai panen : Rp 3500000

# %%
print("Halo, Google Colab!")
# Out:
# Halo, Google Colab!
